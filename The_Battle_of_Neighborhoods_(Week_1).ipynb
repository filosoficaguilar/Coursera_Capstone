# %% [markdown]
# <a href="https://colab.research.google.com/github/filosoficaguilar/Coursera_Capstone/blob/main/The_Battle_of_Neighborhoods_(Week_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>The Battle of Neighborhoods (Week 1).</h1>

# %% [markdown]
# <h2>Introduction/Business Problem</h2>

# %% [markdown]
# Mexico City (CDMX) is the capital of Mexico, this is one of the most populous cities in North America, this city is the largest city in Mexico and has a population of 8,855 million (2015).
#
# Is a good place to visit on holly days but if you are an outsider maybe you can't choose what to do.
#
# This project has the purpose of comparing where is the best place or neighborhood stay on your travel.

# %% [markdown]
# <h2>Data Section</h2>

# %% [markdown]
# To this project, we will use one csv file cointaining the main location of the Mexico City, the csv file contains 9 columns: COLONIA,ENTIDAD	Geo Point,Geo Shape,CVE_ALC	ALCALDIA,CVE_COL	SECC_COM,SECC_PAR, we need only COLONIA as neighborhood and Geo Point as latitude and longitude, you can see the csv file on https://datos.cdmx.gob.mx/explore/dataset/coloniascdmx/download/?format=csv&timezone=America/Mexico_City&lang=es&use_labels_for_header=true&csv_separator=%2C
#
# The Figure bellow present the dataframe created from the csv file.

# %% [markdown]
# <h2>Dataframe of Mexico City neighborhood:</h2>

# %% [markdown]
# Original CSV dataframe
# ![Captura de pantalla de 2020-10-14 14-38-12.png](data:image/png;base64,...)

# %% [markdown]
# Clean Dataframe
#
# ![Captura de pantalla de 2020-10-14 15-00-23.png](data:image/png;base64,...)

# %% [markdown]
# Map with all the Neighborhoods
#
# ![Captura de pantalla de 2020-10-14 15-40-42.png](data:image/png;base64,...)

# %% [markdown]
# With these dataframe, we will use Foursquare development account to find all the venues where you can go and where are there.
#
# The Figure below shows the result of the Foursquare requisition.

# %% [markdown]
# ![Captura de pantalla de 2020-10-14 16-06-30.png](data:image/png;base64,...)

# %% [markdown]
# With this DataFrame of venues we can start to create a map with all the venues and all the Neighborhoods to know where is the best place to stay
